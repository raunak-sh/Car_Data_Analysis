# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Importing Dataset

# %%
data= pd.read_csv("car_details_v4.csv")

# %%
data
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %%
data.shape
# Out:
# (2059, 20)

# %%
data.tail(20)
# Out:
#                Make                                    Model    Price  Year  \
# 2039  Mercedes-Benz                             B-class B180  1150000  2014
# 2040          Honda                              City SV CVT   590000  2015
# 2041  Mercedes-Benz             C-Class C 220 CDI Avantgarde  2450000  2014
# 2042      Chevrolet                        Sail Sedan 1.2 LS   299000  2014
# 2043  Mercedes-Benz             C-Class C 220 CDI Avantgarde  2850000  2016
# 2044       Mahindra  XUV700 AX 7 Petrol AT Luxury Pack 7 STR  2765000  2022
# 2045  Maruti Suzuki                      Wagon R LXI CNG (O)   365000  2014
# 2046  Maruti Suzuki                        Vitara Brezza ZDi   850000  2018
# 2047          Honda                                   City V   480000  2015
# 2048        Hyundai      Grand i10 Asta 1.1 CRDi [2013-2016]   345000  2016
# 2049  Mercedes-Benz                           GLS 400 4MATIC  5950000  2017
# ...

# %% [markdown]
# # 2. Data Cleaning

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (2059, 20)

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Price                   0
# Year                    0
# Kilometer               0
# Fuel Type               0
# Transmission            0
# Location                0
# Color                   0
# Owner                   0
# Seller Type             0
# Engine                 80
# Max Power              80
# Max Torque             80
# Drivetrain            136
# Length                 64
# Width                  64
# Height                 64
# Seating Capacity       64
# Fuel Tank Capacity    113
# dtype: int64

# %%
data= data.dropna()

# %% [markdown]
# # 3. Data Analysis

# %%
cor= data.corr()
sns.heatmap(cor,annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %% [markdown]
# # Price vs Year

# %%
sns.barplot(data.Year,data.Price)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Nitro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Price vs Seat Capacity

# %%
sns.barplot(x='Seating Capacity' ,y= 'Price',data=data)
plt.show()

# %% [markdown]
# # Price vs Fuel Tank Capcity

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(x='Fuel Tank Capacity', y='Price', data=data, ax=ax)

# Rotate the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# Set the title of the plot
ax.set_title('Price vs Fuel Tank Capacity')

# Show the plot
plt.show()

# %% [markdown]
# # 4. Questions

# %% [markdown]
# - 10 Most expensive car
# - Most oldest car
# - Most car manufracturer company
# - 10 Low budget car
# -

# %% [markdown]
# ## I. 10 Most expensive car

# %%
data.nlargest(10, 'Price').loc[:, ['Make', 'Model','Price']]
# Out:
#                Make                                Model     Price
# 483         Ferrari                              488 GTB  35000000
# 1305     Land Rover  Range Rover 3.0 V6 Diesel Vogue LWB  27500000
# 582      Land Rover      Range Rover 3.0 V6 Diesel Vogue  22000000
# 1246    Rolls-Royce             Ghost Extended Wheelbase  20000000
# 1369    Rolls-Royce             Ghost Extended Wheelbase  20000000
# 1890  Mercedes-Benz                        S-Class S 450  20000000
# 1313     Land Rover      Range Rover 3.0 V6 Diesel Vogue  19300000
# 442   Mercedes-Benz                S-Class Maybach S 560  18500000
# 1912  Mercedes-Benz           S-Class S 350D [2018-2020]  18500000
# 977     Rolls-Royce                            Ghost 6.5  18000000

# %% [markdown]
# ## II. Most oldest car

# %%
data.nsmallest(10,'Year').loc[:, ['Year','Make', 'Model','Price']]
# Out:
#       Year           Make                        Model    Price
# 995   1988  Mercedes-Benz     E-Class E 200 Avantgarde  1300000
# 68    2006          Honda                Civic 1.8S MT   190000
# 164   2006          Honda                  CR-V 2.4 AT   250000
# 135   2007       Mahindra      Scorpio 2.6 Turbo 7 Str   550000
# 470   2007  Maruti Suzuki     Grand Vitara 2015 2.0 AT   345000
# 846   2007  Mercedes-Benz                  S-Class 350   750000
# 406   2008  Maruti Suzuki            Wagon R LXi Minor   160000
# 1250  2008  Mercedes-Benz  C-Class 220 CDI Elegance AT   495000
# 1268  2008  Maruti Suzuki            Wagon R LXi Minor   218000
# 1517  2008        Hyundai                i10 Magna (O)   150000

# %% [markdown]
# ## III. Most car manufracturer company

# %%
data.Make.unique()
# Out:
# array(['Honda', 'Maruti Suzuki', 'Hyundai', 'Toyota', 'BMW', 'Skoda',
#        'Nissan', 'Renault', 'Tata', 'Volkswagen', 'Ford', 'Mercedes-Benz',
#        'Audi', 'Mahindra', 'MG', 'Jeep', 'Porsche', 'Kia', 'Land Rover',
#        'Volvo', 'Maserati', 'Jaguar', 'Isuzu', 'MINI', 'Ferrari',
#        'Mitsubishi', 'Datsun', 'Chevrolet', 'Ssangyong', 'Fiat',
#        'Rolls-Royce', 'Lexus'], dtype=object)

# %%
data['Make'].value_counts()
# Out:
# Maruti Suzuki    398
# Hyundai          333
# Mercedes-Benz    159
# Honda            149
# Toyota           123
# Audi             118
# Mahindra         110
# BMW               89
# Ford              47
# Tata              47
# Renault           43
# Volkswagen        42
# Skoda             37
# Land Rover        30
# Kia               23
# Jeep              16
# Volvo             16
# Nissan            15
# Jaguar            13
# MG                13
# Porsche           12
# MINI               9
# Datsun             8
# Lexus              5
# Mitsubishi         4
# Chevrolet          4
# Ssangyong          3
# Rolls-Royce        3
# Isuzu              2
# Maserati           1
# Ferrari            1
# Fiat               1
# Name: Make, dtype: int64

# %%
data['Model'].value_counts()
# Out:
# X1 sDrive20d xLine                       15
# Swift DZire VDI                          14
# City V                                   13
# Fortuner 2.8 4x2 AT [2016-2020]          13
# Swift VXi                                12
#                                          ..
# Grand i10 Asta 1.2 Kappa VTVT             1
# A3 40 TFSI Premium Plus + sunroof         1
# E-Class E 350 d Exclusive [2017-2019]     1
# Pajero SFX 2.8                            1
# Figo Duratec Petrol ZXI 1.2               1
# Name: Model, Length: 955, dtype: int64

# %% [markdown]
# ## IV. 10 Low budget car

# %%
data.nsmallest(10, 'Price').loc[:, ['Make', 'Model','Price']]
# Out:
#                Make                     Model   Price
# 491            Tata                 Nano Base   49000
# 1701        Hyundai                   i10 Era  130000
# 1337        Hyundai                Santro GLS  141000
# 34          Hyundai           Santro GL (CNG)  145000
# 264   Maruti Suzuki         Wagon R LXi Minor  145000
# 1517        Hyundai             i10 Magna (O)  150000
# 1038  Maruti Suzuki              Alto LXi CNG  155000
# 1505  Maruti Suzuki              Alto LXi CNG  155000
# 406   Maruti Suzuki         Wagon R LXi Minor  160000
# 518   Maruti Suzuki  Alto VXi (O) [2014-2019]  160000

# %% [markdown]
# # 5.

# %%
x_features=['Length','Fuel Tank Capacity','Year']
x_train= data[x_features].values
y_train= data[['Price']].values

# %%
fig,ax=plt.subplots(1,3,figsize=(12,5),sharey=True)
for i in range(len(ax)):

    ax[i].scatter(x_train[:,i],y_train,label='Actual data')
    ax[i].set_xlabel(x_features[i])
ax[0].set_ylabel('Price')
plt.show()

# %% [markdown]
# # 5. Normalization of Date

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_norm = scaler.fit_transform(x_train)

# %%
x_norm
# Out:
# array([[-0.66844738, -1.13546877,  0.09132752],
#        [-0.65698224, -0.67382486, -0.86480526],
#        [-1.59712421, -1.13546877, -1.82093804],
#        ...,
#        [-1.80349684, -1.33331616, -0.86480526],
#        [-1.11558808, -0.47597746, -1.18351619],
#        [ 1.50075825,  0.84300514,  0.41003844]])

# %%
fig,ax=plt.subplots(1,3,figsize=(12,5),sharey=True)
for i in range(len(ax)):

    ax[i].scatter(x_norm[:,i],y_train,label='Actual data')
    ax[i].set_xlabel(x_features[i])
ax[0].set_ylabel('Price')
plt.show()

# %% [markdown]
# # Splitting Data into Train and Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_norm, x_train,test_size=0.2,random_state=42)

# %%
y_train.shape
# Out:
# (1499, 3)

# %%
y_test.shape
# Out:
# (375, 3)
